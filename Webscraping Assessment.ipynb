# %% [markdown]
# Before attempting to scrape any website, it is crucial to review and adhere to the website’s terms of service, robots.txt file, and any other guidelines or restrictions they may have in place.

# %%
import selenium
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
import time
from bs4 import BeautifulSoup
from selenium.common.exceptions import NoSuchElementException  
import pandas as pd

# Setup Chrome WebDriver
service = Service(ChromeDriverManager().install())
driver = webdriver.Chrome(service=service)

# Navigate to the website
URL = "https://sherni.inflibnet.ac.in/"
driver.get(URL)

# Find the "Profile" button element
view_buttons = driver.find_elements(By.LINK_TEXT, "View Profile")

# Initialize an empty DataFrame
data = []

# Iterate through each button and click it using JavaScript
for button in view_buttons:
    try:
        driver.execute_script("arguments[0].click();", button)
        time.sleep(2)  # Wait for the profile page to load
        
        # Switch to the newly opened tab or window
        driver.switch_to.window(driver.window_handles[-1])
        
        time.sleep(2)
        
        # Get the HTML content of the page
        page_source = driver.page_source

        # Parse the HTML content with BeautifulSoup
        soup = BeautifulSoup(page_source, "html.parser")

        card = driver.find_element(By.CLASS_NAME, "name-location")

        time.sleep(3)

        # Extract name, designation, and institute name
        name = card.find_element(By.TAG_NAME, "h1").text

        uni = card.find_elements(By.TAG_NAME, "li")[-1].text
        #uni = ', '.join([element.text for element in uni_element])

        expertise = driver.find_element(By.ID, "e_expertise").text
        prof = driver.find_element(By.CSS_SELECTOR, ".cbp_tmlabel h2").text

        # Scroll down to load the paper
        driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
        time.sleep(10)  # Wait for the paper to load
        
        try:
            paper = driver.find_element(By.CSS_SELECTOR, "#publication_div h2").text
        except NoSuchElementException:
            paper = "No paper found"
        
        try:
            educ = driver.find_element(By.ID, "qualification-view").text.replace('\n', ' ')
        except NoSuchElementException:
            educ = "Educational qualification not available"
            
        # Append the extracted details to the data list
        data.append([name, uni, expertise, prof, paper, educ])

        # Close the current tab or window and switch back to the main page
        driver.close()
        driver.switch_to.window(driver.window_handles[0])
        
    except NoSuchElementException:
        # Increment error count if NoSuchElementException occurs
        error_count += 1
        print("Error: NoSuchElementException encountered. Skipping this profile.")
        # Close the current tab or window and switch back to the main page
        driver.close()
        driver.switch_to.window(driver.window_handles[0])

# Close the browser
driver.quit()

# Create a DataFrame from the collected data
df = pd.DataFrame(data, columns=['Faculty Name', 'Institute Name', 'Subject Expertise', 'Designation', 'Most Recent Work', 'Education Qualification'])

# Print the DataFrame
df
# Out:
# Error: NoSuchElementException encountered. Skipping this profile.
#                       Faculty Name  \
# 0             Prof Rekha S Singhal
# 1          Prof Madhoolika Agrawal
# 2              Prof Anushree Malik
# 3            Prof Paramjit Khurana
# 4              Dr. Seghal Kiran G.
# 5               Prof Purnima Singh
# 6                  Dr Kavita Singh
# 7                   Ms Pooja Tyagi
# 8                    Dr Ravi Kiran
# 9                      Dr Devika J
# 10                     Dr T Devaki
# 11       Prof Dr. Neelam S Sangwan
# 12           Prof Satyawati Sharma
# 13             Dr Geeta K Vemugant
# 14             Prof Nikhat Manzoor
# 15     Dr Mannepalli Lakshmikantam
# 16              Dr Judith Vijaya J
# 17               Dr Pankaj Raizada
# 18               Dr Sadhana Rayalu
# 19           Dr Meenakshi Sankaran
# 20            Prof Veena Choudhary
# 21  Prof Sanghamitra Bandyopadhyay
# 22            Prof Jayashree Bijwe
# 23                Prof Richa Singh
# 24           Dr Paramita Mukherjee
# 25         Prof Perumal Yogeeswari
# 26            Prof Sanjula Baboota
# 27          Dr Sushama Talegaonkar
# 28               Dr Sarwat Sultana
# 29                Prof Kavita Shah
# 30     Dr Jyothsna Rani Komaragiri
# 31                 Dr Seema Sharma
# 32                Prof ANJU Bhasin
# 33            Prof Suman Bala Beri
# 34           Prof Devika P Madalli
# 35                Dr Amritpal Kaur
# 36                Dr Baerbel Sinha
# 37               Prof Seema Sharma
# 38             Prof Usha K Aravind
#
#                                        Institute Name  \
# 0            Institute of Chemical Technology, Mumbai
# 1                            Banaras Hindu University
# 2                Indian Institute of Technology Delhi
# 3                                 University of Delhi
# 4                              Pondicherry University
# 5                Indian Institute of Technology Delhi
# 6                         Jawaharlal Nehru University
# 7       Noida Institute of Engineering and Technology
# 8      Thapar Institute of Engineering and Technology
# 9                      Centre for Development Studies
# 10                               University of Madras
# 11                      Central University of Haryana
# 12               Indian Institute of Technology Delhi
# 13                            University of Hyderabad
# 14                               Jamia Millia Islamia
# 15           Institute of Chemical Technology, Mumbai
# 16                            Loyola College, Chennai
# 17                                Shoolini University
# 18  CSIR-National Environmental Engineering Resear...
# 19                         Gandhigram Rural Institute
# 20               Indian Institute of Technology Delhi
# 21                       Indian Statistical Institute
# 22               Indian Institute of Technology Delhi
# 23             Indian Institute of Technology Jodhpur
# 24                   Variable Energy Cyclotron Centre
# 25  Birla Institute of Technology and Science, Pilani
# 26                                      Jamia Hamdard
# 27                                      Jamia Hamdard
# 28                                      Jamia Hamdard
# 29                           Banaras Hindu University
# 30             Indian Institute of Science, Bangalore
# 31  Indian Institute of Science Education and Rese...
# 32                                University of Jammu
# 33                      Panjab University, Chandigarh
# 34             Information and Library Network Centre
# 35                          Guru Nanak Dev University
# 36  Indian Institute of Science Education and Rese...
# 37               Indian Institute of Technology Delhi
# 38        Cochin University of Science and Technology
#
#                            Subject Expertise           Designation  \
# 0                Food Science and Technology             Professor
# 1                     Environmental Sciences             Professor
# 2                   Agricultural Engineering             Professor
# 3                             Plant Sciences             Professor
# 4                Food Science and Technology   Assistant Professor
# 5              Humanities, Multidisciplinary       Professor (HAG)
# 6                                        Art             Professor
# 7                   Language and Linguistics   Assistant Professor
# 8              Humanities, Multidisciplinary             Professor
# 9              Literary Theory and Criticism   Associate Professor
# 10                     Miscellaneous Biology             Professor
# 11                                   Biology             Professor
# 12                     Miscellaneous Biology       Professor (HAG)
# 13                                   Biology             Professor
# 14                                  Mycology             Professor
# 15                        Physical Chemistry             Professor
# 16                         Applied Chemistry                  Dean
# 17           Inorganic and Nuclear Chemistry   Associate Professor
# 18                      Analytical Chemistry       Chief Scientist
# 19                         Applied Chemistry             Professor
# 20                Materials Science Textiles             Professor
# 21                                         7              Director
# 22                    Industrial Engineering             Professor
# 23  Computer Science Artificial Intelligence             Professor
# 24       Materials Science Multidisciplinary  Scientific Officer H
# 25                 Pharmacology and Pharmacy      Senior Professor
# 26                 Pharmacology and Pharmacy             Professor
# 27                 Pharmacology and Pharmacy   Assistant Professor
# 28                                Toxicology   Associate Professor
# 29        Biochemistry and Molecular Biology             Professor
# 30                           Nuclear Physics   Assistant Professor
# 31                 Multidisciplinary Physics   Associate Professor
# 32              Particles and Fields Physics                  Dean
# 33              Particles and Fields Physics             Professor
# 34           Library and Information Science              Director
# 35           Library and Information Science             Professor
# 36                     Environmental Studies   Associate Professor
# 37                                Management             Professor
# 38                     Environmental Studies             Professor
#
#                                      Most Recent Work  \
# 0   Co-extraction of marigold flowers (Tagetes ere...
# 1   Secondary metabolites responses of plants expo...
# 2   An integration of algae-mediated wastewater tr...
# 3   Identification of universal stress proteins in...
# 4   Genomic investigation unveils high-risk ESBL p...
# 5   Haptoglobin Gene Expression and Anthracycline-...
# 6   Exploring synergies between India's climate ch...
# 7   Development of copper nanoparticles and their ...
# 8   Understanding the relevance of experiential le...
# 9   The kiss of love protests: A report on resista...
# 10  Baicalein inhibits cell proliferation and enha...
# 11  Differential regulation of key triterpene synt...
# 12  Vitamin B12: Strategies for enhanced productio...
# 13  2022 A study of the appeal of celebrity endors...
# 14  Limonene inhibits virulence associated traits ...
# 15  Fluorapatite-Supported Palladium Catalyst for ...
# 16  The cytotoxic effectiveness of Thiourea-reduce...
# 17  Sustainability, performance, and production pe...
# 18  ‘Green firecrackers’ with reduced barium emiss...
# 19  Applications of chitin and chitosan based biom...
# 20  Boosting selectivity and sensitivity to biomar...
# 21  SoURA: a user-reliability-aware social recomme...
# 22  A comparative assessment of nano and micropart...
# 23  Corruption depth: Analysis of DNN depth for mi...
# 24                                     No paper found
# 25  Targeting hexokinase 2 for oral cancer therapy...
# 26  Ribociclib Nanostructured Lipid Carrier Aimed ...
# 27  Hybrid chitosan-based nanoparticulate systems ...
# 28  Amelioration of N,N′-dimethylhydrazine induced...
# 29  LIMK2: A Multifaceted kinase with pleiotropic ...
# 30  Study of azimuthal anisotropy of ϒ(1S) mesons ...
# 31  Observation of WZγ Production in pp Collisions...
# 32  K∗0 production in Au+Au collisions at sNN =7.7...
# 33  Measurement of the production cross section fo...
# 34  DMPFrame: A Conceptual Metadata Framework for ...
# 35  Implications of physicochemical properties of ...
# 36  Nocturnal pollutant uptake contributes signifi...
# 37  Role of corporate governance in asset quality ...
# 38  Layer-by-layer assembled graphitic carbon nitr...
#
#                               Education Qualification
# 0                                               Ph.D.
# 1        1982 Ph.D Banaras Hindu University, Varanasi
# 2      2000 PhD Indian Institute of Technology, Delhi
# 3                       1983 Ph.D University of Delhi
# 4             Educational qualification not available
# 5          D.Phil. University of Allahabad, Allahabad
# 6                         1996 Ph.D Panjab University
# 7                         2002 MA D G college, Kanpur
# 8   1999 Ph.D Thapar Institute of Engineering and ...
# 9   2003 Ph.D (History) Mahatma Gandhi University,...
# 10                                               Ph.D
# 11                    1989 Ph.D University of Lucknow
# 12                                         1987 Ph.D.
# 13  1994 M.D. Nizam's Institute of Medical Science...
# 14                                                PhD
# 15  1982 Ph.D. (Physical Chemistry) Kurukshetra Un...
# 16                   2007 Ph.D Loyola College Chennai
# 17                      2011 Ph.D Shoolini University
# 18                                                PhD
# 19               2019 Ph.D Gandhigram Rural Institute
# 20            Educational qualification not available
# 21    1998 Ph.D Indian Statistical Institute, Kolkata
# 22                               1989 Ph.D. IIT DELHI
# 23  2008 Ph.D. West Virginia University, Morgantow...
# 24                     2004 Ph.D. Jadavpur University
# 25                 2001 Ph.D Banaras Hindu University
# 26                 1995 Ph.D Jamia Hamdard University
# 27                                               Ph.D
# 28                                               Ph.D
# 29                 1992 Ph.D Banaras Hindu University
# 30  2005 Ph.D. Tata Institute of Fundamental Resea...
# 31  Ph.D Tata Institute of Fundamental Research (T...
# 32                      1992 Ph.D University of Jammu
# 33            1976 Ph.D Panjab University, Chandigarh
# 34                                              Ph.D.
# 35                                              Ph.D.
# 36  2007 PhD Max Planck Institute for Chemistry Ge...
# 37                                    Ph.D. IIT Delhi
# 38  1996 Ph.d Cochin University of Science and Tec...

# %%
# Save the DataFrame to a CSV file
df.to_csv('SHERNI_faculty_profiles.csv', index=False)

# %% [markdown]
# ## Steps Taken & Challenges Faced:
#
# - Using Selenium WebDriver, the script first navigates to the Sherni platform
# - By finding elements with the link text "View Profile," the script identifies buttons to view individual profiles
# - I iterate through each "View Profile" button and click it using JavaScript execution
# - Upon clicking a profile button, a new tab or window opens. The script switches to this new tab to extract profile information
# - Various methods are employed to locate and extract each piece of information:
#
# **Name, Designation, and Institute Name:** Extracted directly from specific elements on the page.
#
# **Subject Expertise:** Located by its unique ID and extracted.
#
# **Most Recent Work:** Extracted from the "Publications" section, if available.
#
# **Educational Qualifications:** Extracted from the "Qualifications" section, if available.
# - To ensure complete data retrieval, the script scrolls down the page to load additional content
# - NoSuchElementException is also handled when attempting to extract information that may not be present on all profiles
# - After extracting information from a profile, the script closes the current tab/window and switches back to the main page to proceed to the next profile

# %%
import selenium
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
import time
from bs4 import BeautifulSoup
from selenium.common.exceptions import NoSuchElementException  
import pandas as pd
from selenium.webdriver.common.action_chains import ActionChains

# Setup Chrome WebDriver
service = Service(ChromeDriverManager().install())
driver = webdriver.Chrome(service=service)

# Navigate to the webpage
URL = "https://www.iima.ac.in/"
driver.get(URL)

time.sleep(3)

# Find the element with ID "nav-icon3" and click it
nav_icon = driver.find_element(By.ID, "nav-icon3")
nav_icon.click()

faculty_and_research_option = driver.find_element(By.LINK_TEXT, "Faculty & Research")
# Hover over the "Faculty & Research" option
action = ActionChains(driver)
action.move_to_element(faculty_and_research_option).perform()

# Add a brief pause to see the cursor movement (optional)
time.sleep(2)  # Adjust the sleep duration as needed

# Scroll to the right to view more options inside it
#driver.execute_script("arguments[0].scrollIntoView();", faculty_and_research_option)
# Scroll to the right by a percentage of the document width
driver.execute_script("window.scrollBy(document.body.scrollWidth * 0.5, 0);")

# After expanding the menu and moving the cursor to view more options

# Find the "Our Faculty" option by link text
our_faculty_option = driver.find_element(By.LINK_TEXT, "Our Faculty")

# Click on the "Our Faculty" option
our_faculty_option.click()

time.sleep(2)

faculty_info = []

# Outer loop to navigate through multiple pages
while True:
    # Scroll down to load the paper
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
    
    cards = driver.find_elements(By.CLASS_NAME, "faculty-card-detail")

    for card in cards:
        driver.execute_script("arguments[0].click();", card)
    
        time.sleep(2)
        # Find the name of the person
        name = driver.find_element(By.TAG_NAME,"h3").text
    
        # Profession
        prof = driver.find_element(By.TAG_NAME, "p").text
    
        # Find the parent div element
        parent_div = driver.find_element(By.CLASS_NAME, "employee-area-box")

        # Find the p tag inside the parent div and get its text
        expertise = parent_div.find_element(By.TAG_NAME, "p").text.split(":")[-1].strip()
    
        # Scroll down to load the paper
        driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
    
        # Wait for 2 secs
        time.sleep(2)
    
        # For Education background and Reasearch Work, class is "field elements"
        # Scrape educational qualifications
        try:
            educ_parent_div = driver.find_element(By.CLASS_NAME, "field--name-field-academic-degrees-education")
            educ_items = educ_parent_div.find_elements(By.TAG_NAME, "p")

            educational_qualifications = ""
            for educ_item in educ_items:
                educational_qualifications += educ_item.text.strip() + " "
        except NoSuchElementException:
            educational_qualifications = "Not Found"
    
        # Scrape research area
        try:
            research_parent_div = driver.find_element(By.CLASS_NAME, 'last-p-margin-0')
            research_items = research_parent_div.find_elements(By.TAG_NAME, "p")
            research_areas = ""
            for research_item in research_items:
                research_areas += research_item.text.strip() + " "
        except NoSuchElementException:
            research_areas = "Not Found"
        
        # Append faculty information to the list
        faculty_info.append({
            "Name": name,
            "Profession": prof,
            "Area of Expertise": expertise,
            "Educational Background": educational_qualifications,
            "Research Area": research_areas
        })
        
        driver.back()
    
    # Find all the page elements
    pages = driver.find_elements(By.CLASS_NAME, "pager__item")
    
    # Check if there is a "Next" page
    next_page_link = None
    for page in pages:
        if "Next" in page.text:
            next_page_link = page.find_element(By.TAG_NAME, "a")
            break
    
    # If there is no "Next" page, exit the loop
    if not next_page_link:
        break
    
    # Scroll to the next page link and click it
    driver.execute_script("arguments[0].scrollIntoView();", next_page_link)
    
    # Click on the next page link
    driver.execute_script("arguments[0].click();", next_page_link)
    
# Close the driver
driver.quit()

# Convert the list of dictionaries to a DataFrame
df = pd.DataFrame(faculty_info)

df
# Out:
#                       Name                                         Profession  \
# 0              Saravanan A                    Assistant Professor of Strategy
# 1           Anurag Agarwal                    Associate Professor of Strategy
# 2          Promila Agarwal  Associate Professor of Human Resources Management
# 3        Sobhesh Agarwalla                Professor of Finance and Accounting
# 4         Anirban Banerjee      Assistant Professor of Finance and Accounting
# ..                     ...                                                ...
# 99    Prahalad Venkateshan  Associate Professor of Operations and Decision...
# 100           Sanjay Verma         Associate Professor of Information Systems
# 101  Akshaya Vijayalakshmi                   Associate Professor of Marketing
# 102         Vineet Virmani      Associate Professor of Finance and Accounting
# 103         Neharika Vohra              Professor of Organisational Behaviour
#
#                     Area of Expertise  \
# 0                            Strategy
# 1
# 2
# 3              Finance and Accounting
# 4              Finance and Accounting
# ..                                ...
# 99   Operations and Decision Sciences
# 100
# 101
# 102
# 103
#
#                                 Educational Background  \
# 0    Ph.D., International Investment Law, Indian In...
# 1    LL.D. Doctor of Laws , (Lucknow University) – ...
# 2    Ph.D, Faculty of Management Studies, Universit...
# 3                            Ph.D., IIMA FCA ACS ACMA
# 4    Ph.D, Finance, Indian Institute of Management ...
# ..                                                 ...
# 99   Bachelor of Engineering, College of Engineerin...
# 100  Fellow , Indian Institute of Management Calcut...
# 101                                          Not Found
# 102     Fellow, Economics, IIMA B. Tech, Mech, IT-BHU
# 103  Ph.D, Social Psychology, University of Manitob...
#
#                                          Research Area
# 0    International Investment Law Intellectual Prop...
# 1    International Business Dispute Resolution Arbi...
# 2    High-Performance Work Systems Dark Triad Perso...
# 3
# 4                                            Not Found
# ..                                                 ...
# 99   Vehicle Routing Facility Location Network Desi...
# 100  E-Governance Knowledge Management Multiple Res...
# 101  Broadly: Marketing and Public Policy Specifica...
# 102                                          Not Found
# 103  Cross-cultural behavior Discipline development...
#
# [104 rows x 5 columns]

# %%
df.to_csv('IIMA_faculty_profiles.csv', index=False)

# %% [markdown]
# ## Steps Taken & Challenges Faced:
#
# - Once the driver has been implemented and the IIMA main webpage opens, we can see a 3 bar navigation icon on the top-right corner of the page. My code uses Selenium to interact with such elements. In this case, it clicks it.
# - A drop down menu opens up wherein our code hovers on the "Faculty & Research" option to make the next drop down visible. There were challenges in doing this since the two lists almost overlap each other but I resolved it by putting a code that would scroll to the right once it reaches the "Faculty & Research" option.
# - From here, we will click on the "Our Faculty" link
# - In the new webpage, we iterate (loop) through all the page numbers (as can be seen on the bottom of the webpage)
# - For each page, the code opens each faculty profile and webscrapes their name, profession, expertise area, educational background and research work.
# - Some more challenges I resolved included things like adding a scrolling element for each faculty page for it to load all the elements necessary for webscraping, adding wait times and finding unique class/tag names.
# - Another challenge was that some faculty pages did not have education and research area elements so I had to make a counter for it in order to let my code loop run all the way till the end
#
# **NOTE: Unlike the SHERNI website, there wasn't any specific "year" or "university" element that I could scrape separately. The educational background element has the combined information.**
